# %%
import os
import tensorflow as tf 
from PIL import Image
i=0
example = {}
for serialized_example in tf.python_io.tf_record_iterator("output.tfrecord"):
    example[i] = tf.train.SequenceExample.FromString(serialized_example)
    i += 1
# Out:
# ---------------------------------------------------------------------------
# DataLossError                             Traceback (most recent call last)
# <ipython-input-59-b66d66fbda3d> in <module>()
#       4 i=0
#       5 example = {}
# ----> 6 for serialized_example in tf.python_io.tf_record_iterator("output.tfrecord"):
#       7     example[i] = tf.train.SequenceExample.FromString(serialized_example)
#       8     i += 1
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/lib/io/tf_record.py in tf_record_iterator(path, options)
#     179     while True:
#     180       try:
# --> 181         reader.GetNext()
#     182       except errors.OutOfRangeError:
#     183         break
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in GetNext(self)
#     795
#     796     def GetNext(self):
# --> 797         return _pywrap_tensorflow_internal.PyRecordReader_GetNext(self)
#     798
#     799     def record(self):
#
# ...

# %%
print (example[0])
# Out:
# context {
#   feature {
#     key: "labels"
#     value {
#       int64_list {
#         value: 1535
#       }
#     }
#   }
#   feature {
#     key: "predictions"
#     value {
#       float_list {
#         value: 2.923951943657557e-18
#         value: 1.9085437273700767e-26
#         value: 0.001518503064289689
#         value: 0.0
#         value: 0.0
#         value: 1.03746357208237e-14
#         value: 0.0
#         value: 3.0548073937097797e-06
#         value: 0.0
#         value: 0.0
#         value: 1.6376307013456347e-37
#         value: 0.0
#         value: 2.105806915185772e-23
#         value: 4.0702511638571043e-32
#         value: 0.0
#         value: 5.15205407887264e-16
#         value: 5.671598148334418e-16
#         value: 0.0
#         value: 4.465391456431975e-22
#         value: 0.0
#         value: 0.0
#         value: 0.0
#         value: 7.309649859024027e-26
#         value: 0.0
#         value: 0.0
#         value: 1.1183230075756947e-30
# ...
